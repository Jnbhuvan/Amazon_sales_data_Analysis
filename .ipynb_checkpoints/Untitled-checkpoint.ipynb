# %%
import pandas as pd
import numpy as np

amz_df=pd.read_csv('Cleaned Amazon Sale Report.csv');
np.random.seed(0)
amz_df.head(5)
# Out:
# C:\Users\BHUVAN J N\AppData\Local\Temp\ipykernel_14820\938567404.py:4: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   amz_df=pd.read_csv('Cleaned Amazon Sale Report.csv');
#    index             order_id parsed_date   status fulfillment sales_channel  \
# 0  96150  408-4631753-5605964  2022-06-25  pending      amazon     amazon.in
# 1  91239  404-2093011-6135513  2022-06-29  pending    merchant     amazon.in
# 2  91223  407-7926766-7601961  2022-06-29  pending      amazon     amazon.in
# 3  91459  402-1067136-1825927  2022-06-29  pending    merchant     amazon.in
# 4  91662  403-9219853-4911569  2022-06-29  pending    merchant     amazon.in
#
#   ship_service_level   style         sku       category  ... currency amount  \
# 0          expedited  BTM003  BTM003-B-L         bottom  ...      INR    0.0
# 1           standard   J0062  J0062-DR-M  western dress  ...      INR  475.0
# ...

# %%
print(amz_df.dtypes)
# Out:
# index                   int64
# order_id               object
# parsed_date            object
# status                 object
# fulfillment            object
# sales_channel          object
# ship_service_level     object
# style                  object
# sku                    object
# category               object
# size                   object
# asin                   object
# courier_status         object
# qty                     int64
# currency               object
# amount                float64
# ship_city              object
# ship_state             object
# ship_postal_code      float64
# ship_country           object
# promotion_ids          object
# is_b2b                   bool
# fulfilled_by           object
# unnamed_cols           object
# dtype: object

# %%
unique_values = amz_df['ship_city'].unique()
print(len(unique_values))
# Out:
# 686
